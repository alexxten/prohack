# %%
#!pip install pandas-profiling==2.8.0

# %% [markdown]
# # Extract data from zip

# %%
import os
from zipfile import ZipFile

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'prohack_dataset_avOqBYc.zip', 'sample_data']

# %%
path = '/content/data'
os.mkdir(path)

# %%
zip = ZipFile('/content/prohack_dataset_avOqBYc.zip')
zip.extractall(path)

# %% [markdown]
# # Analyse data_train

# %%
import pandas as pd
import pandas_profiling
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('/content/data/train.csv')

# %%
data.head()
# Out:
#    galactic year  ...         y
# 0         990025  ...  0.052590
# 1         990025  ...  0.059868
# 2         990025  ...  0.050449
# 3         990025  ...  0.049394
# 4         990025  ...  0.154247
#
# [5 rows x 80 columns]

# %%
data.tail()
# Out:
#       galactic year  ...         y
# 3860        1015056  ...  0.042324
# 3861        1015056  ...  0.036725
# 3862        1015056  ...  0.166271
# 3863        1015056  ...  0.024187
# 3864        1015056  ...  0.100069
#
# [5 rows x 80 columns]

# %%
print(data.shape)
print(data.dtypes.unique())
# Out:
# (3865, 80)
# [dtype('int64') dtype('O') dtype('float64')]

# %%
data.isna().sum()
# Out:
# galactic year                                                                   0
# galaxy                                                                          0
# existence expectancy index                                                      1
# existence expectancy at birth                                                   1
# Gross income per capita                                                        28
#                                                                              ...
# Adjusted net savings                                                         2953
# Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total    2924
# Private galaxy capital flows (% of GGP)                                      2991
# Gender Inequality Index (GII)                                                3021
# y                                                                               0
# Length: 80, dtype: int64

# %%
profile = pandas_profiling.ProfileReport(data, interactions=None)

# %%
profile.to_file(output_file='Train_data_profile.html')
